# %% [markdown]
# ## Hello Deep Learning
# In the next cell you are going to execute the 'hello world' version of deep learning: The MNIST dataset. Please run the next cell. It is no necessary to understand what's going on in the code. We will learn over the course :)

# %%
import tensorflow as tf

# 1. Load data
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()

# 2. Preprocess data
x_train, x_test = x_train / 255.0, x_test / 255.0

# 3. Define mode's architecture
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

sgd = tf.keras.optimizers.SGD(lr=0.01)
model.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# 4. Train model
model.fit(x_train, y_train, epochs=1, validation_split=0.2)

# 5. Evaluate model
score = model.evaluate(x_test, y_test)
print('Test accuracy:', score[1])
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/1
# ...
# 10000/10000 [==============================] - 1s 73us/step
# Test accuracy: 0.8771

# %% [markdown]
# ### OPTIONAL ASSIGNMENT: Python Refresher
# Replicate on Colab all the code provided in the following tutorial:
# - https://dl7days.page.link/python-tutorial

# %%
class LossHistory(tf.keras.callbacks.Callback):

    def on_epoch_end(self, batch, logs={}):     
         self.training_loss = logs.get('loss')

# %%
import tensorflow as tf

# 1. Load data
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()

# 2. Preprocess data
x_train, x_test = x_train / 255.0, x_test / 255.0

# 3. Define mode's architecture
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

sgd = tf.keras.optimizers.SGD(lr=0.1)
model.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


hist = LossHistory()

# 4. Train model
model.fit(x_train, y_train, epochs=1, validation_split=0.2, callbacks = [hist])

# 5. Evaluate model
score = model.evaluate(x_test, y_test)
print('Test accuracy:', score[1])
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/1
# ...
# 10000/10000 [==============================] - 1s 90us/step
# Test accuracy: 0.9131

# %%
import matplotlib.pyplot as plt
import numpy as np

#plt.plot(history.errors)
#plt.plot(history.errors[-len(history.errors)//10:])
#np.mean(history.errors[-len(history.errors)//10:])
hist.training_loss
# Out:
# 0.8589247224529585

# %%
N_ITERATIONS=100

hist.

learning_rates = np.geomspace(0.0001, 1.0, num=N_ITERATIONS)

plt.plot(range(N_ITERATIONS), learning_rates)

# %%
class LRFinder(self):
  
  def __init__(self):
    self.learning_rates = []
    self.losses = []
  
  @staticmethod
  def _set_lr(optimizer, *lr_):
    return optimizer(*lr_)

  def find(model, optimizer, min_lr=0.0001, max_lr=1.5, n_iter=50):

    hist = LossHistory()

    for lr_ in learning_rates:

      print('Training with Learning Rate = {}'.format(lr_))

      optimiz = self._set_lr(optimizer, lr_)
      model.compile(optimizer=optimiz,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])


      # 4. Train model
      model.fit(x_train[:600], y_train[:600], callbacks = [hist], verbose=0)

      loss = hist.training_loss
      losses.append(loss)

      print('Loss Function = {}'.format(loss))
    
    
  def plot_lrs():
    plt.plot(self.learning_rates, self.losses)
    plt.xscale('log')
    plt.show()

# %%
set_lr(opt, 1)

# %%
base_model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
  ])

opt = tf.keras.optimizers.SGD

lr_search(base_model, opt)
# Out:
# Training with Learning Rate = 0.0001
# Loss Function = 2.4358064206441243
# Training with Learning Rate = 0.00012239850755871998
# Loss Function = 2.432451384862264
# Training with Learning Rate = 0.00014981394652602016
# Loss Function = 2.4283780225118003
# Training with Learning Rate = 0.00018337003466266746
# Loss Function = 2.4234307956695558
# Training with Learning Rate = 0.00022444218573701224
# Loss Function = 2.4173704687754314
# Training with Learning Rate = 0.00027471388567427323
# Loss Function = 2.4100768438975018
# Training with Learning Rate = 0.0003362456961218787
# Loss Function = 2.401216605504354
# Training with Learning Rate = 0.0004115597137836079
# Loss Function = 2.3903754583994545
# Training with Learning Rate = 0.0005037429473840755
# Loss Function = 2.377436882654826
# Training with Learning Rate = 0.0006165738495304159
# Loss Function = 2.3618574492136637
# Training with Learning Rate = 0.0007546771898225767
# Loss Function = 2.3429698944091797
# ...

# %%
N_ITERATIONS=50
MIN_LR = 0.0001
MAX_LR = 2.0



learning_rates = np.geomspace(MIN_LR, MAX_LR, num=N_ITERATIONS)

losses = []

hist = LossHistory()

for lr_ in learning_rates:
  
  print('Training with Learning Rate = {}'.format(lr_))
  
  model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
  ])

  sgd = tf.keras.optimizers.SGD(lr=lr_)
  model.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


  # 4. Train model
  model.fit(x_train[:600], y_train[:600], callbacks = [hist], verbose=0)
  
  loss = hist.training_loss
  losses.append(loss)
  
  print('Loss Function = {}'.format(loss))
# Out:
# Training with Learning Rate = 0.0001
# Loss Function = 2.3398027769724528
# Training with Learning Rate = 0.00012239850755871998
# Loss Function = 2.4204425048828124
# Training with Learning Rate = 0.00014981394652602016
# Loss Function = 2.3360410944620766
# Training with Learning Rate = 0.00018337003466266746
# Loss Function = 2.423543322881063
# Training with Learning Rate = 0.00022444218573701224
# Loss Function = 2.4689855066935222
# Training with Learning Rate = 0.00027471388567427323
# Loss Function = 2.507100445429484
# Training with Learning Rate = 0.0003362456961218787
# Loss Function = 2.327127981185913
# Training with Learning Rate = 0.0004115597137836079
# Loss Function = 2.3595764509836834
# Training with Learning Rate = 0.0005037429473840755
# Loss Function = 2.327347059249878
# Training with Learning Rate = 0.0006165738495304159
# Loss Function = 2.3163118457794187
# Training with Learning Rate = 0.0007546771898225767
# Loss Function = 2.4489325110117592
# ...

# %%
plt.plot(learning_rates, losses)
plt.xscale('log')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-7550a6f54706> in <module>()
# ----> 1 hist.errors
#
# AttributeError: 'Callback' object has no attribute 'errors'
